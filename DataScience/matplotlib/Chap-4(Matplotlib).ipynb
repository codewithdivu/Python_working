# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
# line chart

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 550])
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints,'--')
plt.show()

# %%
# markers

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints,ls='--',c='r',marker='o',linewidth=10)
# plt.plot(xpoints,ypoints,'o-r') # shortcut
plt.show()

# %%
# MultipleLine Chart

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1,ls='--')
plt.plot(y2,ls='-')

plt.show()

# %%
# LABELS

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
# GRID

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()
# plt.grid(axis='y',color='g',linestyle='--',linewidth='2')
plt.show()

# %%
# SUBPLOTS

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
#the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title("first")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.title("second")

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)
plt.title("third")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.title("fourth")

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title("five")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.title("six")

plt.suptitle("6 Charts")
plt.show()

# %%
# PIE CHARTS

# %%
y = np.array([35, 25, 25, 15, 10])

plt.pie(y)
plt.show()

# %%
# Labels
y = np.array([35, 25, 25, 15, 10])
mylabels = ["Apples", "Bananas", "Cherries", "Dates", "Mangoes"]

plt.pie(y, labels = mylabels, shadow=True)
plt.show()

# %%
#Explode
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0.1, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow=True)
plt.show()

# %%
#colors 
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
# legend
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.legend(title='pieChart') # legend with title
plt.show()

# %%
# BAR CHARTS

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y) # for horizontal 

plt.show()

# %%
# color , width
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color='green', width=0.3)

plt.show()

# %%
# HISTOGRAM CHART

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
# You can read from the histogram that there are approximately:

# 2 people from 140 to 145cm
# 5 people from 145 to 150cm
# 15 people from 151 to 156cm
# 31 people from 157 to 162cm
# 46 people from 163 to 168cm
# 53 people from 168 to 173cm
# 45 people from 173 to 178cm
# 28 people from 179 to 184cm
# 21 people from 185 to 190cm
# 4 people from 190 to 195cm

# %%
# BOXPLOT CHART

# %%
data = np.random.randn(100)
plt.boxplot(data)
plt.show()

# %%
# SCATTER PLOT

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()
